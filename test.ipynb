# %%
import pandas

# %%
#asdsadad

# %%
#fsdfsdsdgl

# %%
#asfwqfwq

# %%
#adasdsad

# %%
#이규민

# %%
#ㅁㄴㅇㅁㄴㅇㄴㅁ

# %%
#ㅁㄴㅇㅁㄴㅇㅁㄴㅇ

# %%
#ㅁㄴㅇㅁㄴㅇ

# %%
#ㅁㄴㅇㅁㄴㅇ

# %%
#ㅂㅁㅈㄷㄱㅂㅈㄷㄱㅂㅈㄱ

# %%
#김태훈

# %%
#ㅁㅈㄴㅇㄹㄴㅇㄹ
