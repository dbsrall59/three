# %%
import requests
import json

# %%
keyDict = {"type" : "json", "sDate" : "20181101", "edDate" : "20181102", "numOfRows" : 10, "pageNo" : 1, "key" : "test"}
result = requests.get("http://apis.data.go.kr/B552061/AccidentDeath
", keyDict)
result
# Out:
# <Response [200]>

# %%
result.text
# Out:
# '{"count":313448,"pageNo":1,"numOfRows":10,"pageSize":31345,"trafficFlowBySpeedLists":[{"tcsCarTypeCd":"1","tcsCarTypeNm":"1종","tcsCarTypeGrpNm":"소형차","tcsCarTypeGrpCd":"1","stDate":null,"edDate":null,"oDate":"2010.02.10(수)","stdSpeedCd":"1","trafficFlow":"1782778","stdSpeedNm":"10KM/H미만","message":null,"code":null},{"tcsCarTypeCd":"2","tcsCarTypeNm":"2종","tcsCarTypeGrpNm":"중형차","tcsCarTypeGrpCd":"2","stDate":null,"edDate":null,"oDate":"2010.02.10(수)","stdSpeedCd":"1","trafficFlow":"144720","stdSpeedNm":"10KM/H미만","message":null,"code":null},{"tcsCarTypeCd":"3","tcsCarTypeNm":"3종","tcsCarTypeGrpNm":"대형차","tcsCarTypeGrpCd":"3","stDate":null,"edDate":null,"oDate":"2010.02.10(수)","stdSpeedCd":"1","trafficFlow":"103641","stdSpeedNm":"10KM/H미만","message":null,"code":null},{"tcsCarTypeCd":"4","tcsCarTypeNm":"4종","tcsCarTypeGrpNm":"대형차","tcsCarTypeGrpCd":"3","stDate":null,"edDate":null,"oDate":"2010.02.10(수)","stdSpeedCd":"1","trafficFlow":"68827","stdSpeedNm":"10KM/H미만","message":null,"cod
# ...

# %%
j = json.loads(result.text)

# %%
j['trafficFlowBySpeedLists']
# Out:
# [{'tcsCarTypeCd': '1',
#   'tcsCarTypeNm': '1종',
#   'tcsCarTypeGrpNm': '소형차',
#   'tcsCarTypeGrpCd': '1',
#   'stDate': None,
#   'edDate': None,
#   'oDate': '2010.02.10(수)',
#   'stdSpeedCd': '1',
#   'trafficFlow': '1782778',
#   'stdSpeedNm': '10KM/H미만',
#   'message': None,
#   'code': None},
#  {'tcsCarTypeCd': '2',
#   'tcsCarTypeNm': '2종',
#   'tcsCarTypeGrpNm': '중형차',
#   'tcsCarTypeGrpCd': '2',
#   'stDate': None,
#   'edDate': None,
#   'oDate': '2010.02.10(수)',
#   'stdSpeedCd': '1',
#   'trafficFlow': '144720',
#   'stdSpeedNm': '10KM/H미만',
#   'message': None,
#   'code': None},
#  {'tcsCarTypeCd': '3',
#   'tcsCarTypeNm': '3종',
#   'tcsCarTypeGrpNm': '대형차',
#   'tcsCarTypeGrpCd': '3',
#   'stDate': None,
#   'edDate': None,
#   'oDate': '2010.02.10(수)',
#   'stdSpeedCd': '1',
#   'trafficFlow': '103641',
#   'stdSpeedNm': '10KM/H미만',
#   'message': None,
#   'code': None},
#  {'tcsCarTypeCd': '4',
#   'tcsCarTypeNm': '4종',
#   'tcsCarTypeGrpNm': '대형차',
# ...
