# %%
import pandas as pd
import os

print(os.getcwd())
# Out:
# C:\Users\bigdata\Desktop\three\이규민

# %%
df = pd.read_csv('C:/Users/bigdata/Downloads/tpss_emd_odh_202201/tpss_emd_odh_20220102.csv', sep=',', encoding='euc-kr', encoding_errors='ignore')
df
# Out:
#            기준_날짜  시작_행정동_ID  종료_행정동_ID  승객_수_00  승객_수_01  승객_수_02  승객_수_03  \
# 0       20220102  1116073.0  1116071.0      NaN      NaN      NaN      NaN
# 1       20220102  1101064.0  1102054.0      NaN      NaN      NaN      NaN
# 2       20220102        NaN  1103052.0      NaN      NaN      NaN      NaN
# 3       20220102  1124075.0  1122060.0      NaN      NaN      NaN      NaN
# 4       20220102  2304062.0  1123059.0      NaN      NaN      NaN      NaN
# ...          ...        ...        ...      ...      ...      ...      ...
# 217723  20220102  1105053.0  1114075.0      NaN      NaN      NaN      NaN
# 217724  20220102  1102057.0  3123061.0      NaN      NaN      NaN      NaN
# 217725  20220102  1110064.0  1111072.0      NaN      NaN      NaN      NaN
# 217726  20220102  1108078.0  3120031.0      NaN      NaN      NaN      NaN
# 217727  20220102  1124069.0  3109174.0      NaN      NaN      NaN      NaN
#
# ...

# %%
for i0 in range(2, 5):
    days = 31
    if i0 == 2:
        days = 28
    elif i0 == 4:
        days = 30
        
    for i1 in range(1, days + 1):
        path = 'C:/Users/bigdata/Downloads/tpss_emd_odh_2022' + '{:0>2}'.format(i0) + '/tpss_emd_odh_2022' + '{:0>2}'.format(i0) + '{:0>2}'.format(i1) + '.csv'
        with open(path, mode='r+', encoding='euc-kr', errors='ignore') as f:
            p = f.read()
        with open(path, mode='w', encoding='euc-kr', errors='ignore') as f:
            f.write(p[1:])

# %%
print(p[1:2])
# Out:
# "
