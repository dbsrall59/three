# %%
import os
import multiprocessing
import pandas as pd
import requests
import csv

from bs4 import BeautifulSoup as bs

# %%
df = pd.read_csv('C:/Users/bigdata/Downloads/TR182100150002.csv', sep='|')
df
# Out:
#      YM_ID    CRSRD_ID   TR_VOL   GO_VOL  LEFT_VOL  RIGHT_VOL  UTURN_VOL  \
# 0   202111  1830002000  1530459  1457067     26746      35022      11624
# 1   202111  1830002300   389881   214855     97299      77727          0
# 2   202111  1830002400  1692414   892012    368819     385254      46329
# 3   202111  1830004600  1573474   969496    319425     239445      45108
# 4   202111  1830005200  2913180  1416468    759985     530395     206332
# ..     ...         ...      ...      ...       ...        ...        ...
# 81  202111  1870003600  1365459   606006    320530     385043      53880
# 82  202111  1870003900  1418665   699995    349251     328929      40490
# 83  202111  1870005700  1538195   981501    243435     254023      59236
# 84  202111  1870016600  1154727   807679    163361     165671      18016
# 85  202111  1870020200  1564645   819119    383382     342311      19833
#
#     BIKE_VOL  CAR_VOL  SUV_VOL  VAN_VOL  TRUCK_VOL  BUS_VOL  ETL_TYPE  \
# ...

# %%
f=open(file_path, encoding="utf8")
reader = csv.reader(f)
csv_list=[]
for l in reader:
    csv_list.append(l)
f.close()
log_df = pd.DataFrame(csv_list)
log_df

# %%
csv_list = []
with open(path, encoding='utf8') as f:
    reader = csv.reader(f)
    for i in reader:
        csv_list.append(i)
        
tempdf = pd.DataFrame(csv_list)
tempdf
# Out:
#               0      1         2                   3              4   \
# 0          기준일ID  시간대구분     행정동코드              총생활인구수  남자0세부터9세생활인구수
# 1       20191001     00  11110515  15270.768899999999       526.5168
# 2       20191001     00  11110530  16499.397499999999         541.91
# 3       20191001     00  11110540  5454.6271999999999       115.0705
# 4       20191001     00  11110550          15042.6134       401.3388
# ...          ...    ...       ...                 ...            ...
# 183164  20191031     23  11350612  17632.121899999998       681.3252
# 183165  20191031     23  11170630  29172.271700000001      1316.3336
# 183166  20191031     23  11545710          14687.8462       456.6597
# 183167  20191031     23  11320522  19245.575400000002        958.953
# 183168  20191031     23  11740520  16551.045900000001       368.2088
#
#                         5                   6                   7   \
# 0          남자10세부터14세생활인구수     남자15세부터19세생활인구수     남자20세부터24세생활인구수
# ...

# %%
tempdf.columns = tempdf.iloc[0]
tempdf.rename({tempdf.columns[0] : "기준일ID"}, axis=1,inplace=True)

tempdf
# Out:
# 0          기준일ID  시간대구분     행정동코드              총생활인구수  남자0세부터9세생활인구수  \
# 0          기준일ID  시간대구분     행정동코드              총생활인구수  남자0세부터9세생활인구수
# 1       20191001     00  11110515  15270.768899999999       526.5168
# 2       20191001     00  11110530  16499.397499999999         541.91
# 3       20191001     00  11110540  5454.6271999999999       115.0705
# 4       20191001     00  11110550          15042.6134       401.3388
# ...          ...    ...       ...                 ...            ...
# 183164  20191031     23  11350612  17632.121899999998       681.3252
# 183165  20191031     23  11170630  29172.271700000001      1316.3336
# 183166  20191031     23  11545710          14687.8462       456.6597
# 183167  20191031     23  11320522  19245.575400000002        958.953
# 183168  20191031     23  11740520  16551.045900000001       368.2088
#
# 0          남자10세부터14세생활인구수     남자15세부터19세생활인구수     남자20세부터24세생활인구수  \
# 0          남자10세부터14세생활인구수     남자15세부터19세생활인구수     남자20세부터24세생활인구수
# ...

# %%
df = pd.DataFrame()

for i0 in range(2018, 2022):
    for i1 in range(1, 13):
        year = str(i0) + '{:0>2}'.format(str(i1))
        path = 'C:/Users/bigdata/Downloads/LOCAL_PEOPLE_DONG_{0}/LOCAL_PEOPLE_DONG_{0}.csv'.format(year)
        print(path)
        
        csv_list = []
        with open(path, encoding='utf8') as f:
            reader = csv.reader(f)
            for i in reader:
                csv_list.append(i)
        
        tempdf = pd.DataFrame(csv_list)
        tempdf.columns = tempdf.iloc[0]
        tempdf.rename({tempdf.columns[0] : "기준일ID"}, axis=1,inplace=True)
        
        df = pd.concat([df, tempdf[1:][['기준일ID', '시간대구분', '행정동코드', '총생활인구수']]])

df.to_csv('result.csv', sep=',')
# Out:
# C:/Users/bigdata/Downloads/LOCAL_PEOPLE_DONG_201801/LOCAL_PEOPLE_DONG_201801.csv
# C:/Users/bigdata/Downloads/LOCAL_PEOPLE_DONG_201802/LOCAL_PEOPLE_DONG_201802.csv
# C:/Users/bigdata/Downloads/LOCAL_PEOPLE_DONG_201803/LOCAL_PEOPLE_DONG_201803.csv
# C:/Users/bigdata/Downloads/LOCAL_PEOPLE_DONG_201804/LOCAL_PEOPLE_DONG_201804.csv
# C:/Users/bigdata/Downloads/LOCAL_PEOPLE_DONG_201805/LOCAL_PEOPLE_DONG_201805.csv
# C:/Users/bigdata/Downloads/LOCAL_PEOPLE_DONG_201806/LOCAL_PEOPLE_DONG_201806.csv
# C:/Users/bigdata/Downloads/LOCAL_PEOPLE_DONG_201807/LOCAL_PEOPLE_DONG_201807.csv
# C:/Users/bigdata/Downloads/LOCAL_PEOPLE_DONG_201808/LOCAL_PEOPLE_DONG_201808.csv
# C:/Users/bigdata/Downloads/LOCAL_PEOPLE_DONG_201809/LOCAL_PEOPLE_DONG_201809.csv
# C:/Users/bigdata/Downloads/LOCAL_PEOPLE_DONG_201810/LOCAL_PEOPLE_DONG_201810.csv
# C:/Users/bigdata/Downloads/LOCAL_PEOPLE_DONG_201811/LOCAL_PEOPLE_DONG_201811.csv
# C:/Users/bigdata/Downloads/LOCAL_PEOPLE_DONG_201812/LOCAL_PEOPLE_DONG_201812.csv
# ...

# %%
df = pd.concat([df, pd.read_csv(path, sep=',', index_col=False)[['기준일ID', '시간대구분', '행정동코드', '총생활인구수']]])
df
# Out:
# C:\Users\bigdata\AppData\Local\Temp\ipykernel_1088\1616084102.py:1: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.concat([df, pd.read_csv(path, sep=',', index_col=False)[['기준일ID', '시간대구분', '행정동코드', '총생활인구수']]])
#            기준일ID  시간대구분     행정동코드      총생활인구수
# 0       20180101      0  11110515  14471.4116
# 1       20180101      0  11110530  23059.7992
# 2       20180101      0  11110540   4928.6410
# 3       20180101      0  11110550  14060.9810
# 4       20180101      0  11110560  20322.3298
# ...          ...    ...       ...         ...
# 315451  20180131     23  11740650  34162.7808
# 315452  20180131     23  11740660  27858.2533
# 315453  20180131     23  11740685  63271.8464
# 315454  20180131     23  11740690   6231.4073
# 315455  20180131     23  11740700  34258.3120
#
# [946368 rows x 4 columns]
