# %%
import pandas as pd
import os

print(os.getcwd())
# Out:
# C:\Users\bigdata\Desktop\three\이규민

# %%
df = pd.read_csv('C:/Users/bigdata/Downloads/tpss_emd_odh_202201/tpss_emd_odh_20220101.csv', sep=',', encoding='euc-kr')
df
# Out:
#            기준_날짜  시작_행정동_ID  종료_행정동_ID  승객_수_00  승객_수_01  승객_수_02  승객_수_03  \
# 0       20220101  1112056.0  2305057.0      NaN      NaN      NaN      NaN
# 1       20220101  1113071.0  1113070.0      NaN      NaN      NaN      NaN
# 2       20220101  1102071.0  1125074.0      NaN      NaN      NaN      NaN
# 3       20220101  1105053.0  1110065.0      NaN      NaN      NaN      NaN
# 4       20220101  1104052.0  1102065.0      NaN      NaN      NaN      NaN
# ...          ...        ...        ...      ...      ...      ...      ...
# 210713  20220101  2305057.0  1118057.0      NaN      NaN      NaN      NaN
# 210714  20220101  3126053.0  1110053.0      NaN      NaN      NaN      NaN
# 210715  20220101  1106071.0  1107052.0      NaN      NaN      NaN      NaN
# 210716  20220101  1118053.0  1125056.0      NaN      NaN      NaN      NaN
# 210717  20220101  3110361.0  1115051.0      NaN      NaN      NaN      NaN
#
# ...

# %%
with open('C:/Users/bigdata/Downloads/tpss_emd_odh_202201/tpss_emd_odh_20220101.csv', 'r+') as f:
    p = f.read()
    f.write(p)

# %%
print(p[0:4])
# Out:
# "기준_
