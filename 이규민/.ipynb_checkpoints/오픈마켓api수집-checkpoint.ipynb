# %%
import requests
import json
import multiprocessing
from datetime import datetime

# %%
def threadDivide(getCount, pNum, pCount):
    pNum += 1
    listCount = int(round(getCount / pCount * pNum)) - int(round(getCount / pCount * (pNum - 1)))
    for i in range(listCount):
        print(int(round(getCount / pCount * (pNum - 1))) + i)

# %%
def getProcessCount(pageCount):
    
    keyDict = {
        "key" : "5261015714",
        "type" : "json",
        "numOfRows" : 99,
        "stDate" : 20200101,
        "edDate" : 20220525,
        "pageNo" : 1
    }
    
    manager = multiprocessing.Manager()
    resultList = manager.list()

    startRequest = datetime.today()
    result = requests.get('http://data.ex.co.kr/openapi/trafficOprgPrcd/trafficFlowBySpeed', keyDict)
    endRequest = datetime.today()
    
    if(result.status_code != 200):
        print("에러코드 : {}".format(result.status_code))
        return

    resultList.append(json.loads(result.text))
    endAll= datetime.today()
    
    time1 = endRequest - startRequest
    time2 = endAll - endRequest
    time3 = (endRequest - startRequest) / (endAll - endRequest)
    
    print(time1)
    print(time2)
    print(time3)
    print(pageCount / time3 * 2)
    
getProcessCount(32000)
# Out:
# 0:00:02.194310
# 0:00:00.006085
# 360.6096959737058
# 177.4772024007547

# %%
keyDict = {
    "url" : "http://openapi.seoul.go.kr:8088/",
    "KEY" : "4373706b436b6f7239327256596771",
    "TYPE" : "json",
    "SERVICE" : "ListAirQualityByDistrictService",
    "START_INDEX" : "1",
    "END_INDEX" : "5",
}

urlReal = url + 
# result = requests.get('http://openapi.seoul.go.kr:8088', keyDict)
result = requests.get('http://openapi.seoul.go.kr:8088/4373706b436b6f7239327256596771/json/ListAirQualityByDistrictService/1/100')

print(result)
print(result.text)
# Out:
# <Response [200]>
# {"ListAirQualityByDistrictService":{"list_total_count":25,"RESULT":{"CODE":"INFO-000","MESSAGE":"정상 처리되었습니다"},"row":[{"MSRDATE":"202205271300","MSRADMCODE":"111123","MSRSTENAME":"종로구","MAXINDEX":"73","GRADE":"보통","POLLUTANT":"O3","NITROGEN":"0.008","OZONE":"0.057","CARBON":"0.4","SULFUROUS":"0.003","PM10":"15","PM25":"9"},{"MSRDATE":"202205271300","MSRADMCODE":"111121","MSRSTENAME":"중구","MAXINDEX":"74","GRADE":"보통","POLLUTANT":"O3","NITROGEN":"0.007","OZONE":"0.058","CARBON":"0.3","SULFUROUS":"0.002","PM10":"15","PM25":"10"},{"MSRDATE":"202205271300","MSRADMCODE":"111131","MSRSTENAME":"용산구","MAXINDEX":"81","GRADE":"보통","POLLUTANT":"O3","NITROGEN":"0.008","OZONE":"0.067","CARBON":"0.3","SULFUROUS":"0.003","PM10":"19","PM25":"13"},{"MSRDATE":"202205271300","MSRADMCODE":"111142","MSRSTENAME":"성동구","MAXINDEX":"75","GRADE":"보통","POLLUTANT":"O3","NITROGEN":"0.011","OZONE":"0.059","CARBON":"0.3","SULFUROUS":"0.004","PM10":"27","PM25":"12"},{"MSRDATE":"202205271300","MSRADMCODE":"111141","MSRSTENAME":"광진구","MAXINDEX":"66","GRADE":"보통","POLLUTANT":"O3","NITROGEN":"0
GRADE":"보통","POLLUTANT":"O3","NITROGEN":"0.010","OZONE":"0.065","CARBON":"0.3","SULFUROUS":"0.003","PM10":"18","PM25":"8"},{"MSRDATE":"202205271300","MSRADMCODE":"111231","MSRSTENAME":"영등포구","MAXINDEX":"69","GRADE":"보통","POLLUTANT":"O3","NITROGEN":"0.012","OZONE":"0.052"," ...

# %%
result
# Out:
# <Response [500]>

# %%
manager = multiprocessing.Manager()
resultList = manager.list()

for i in range(1, 3):
    keyDict = {
        "key" : "5261015714",
        "type" : "json",
        "numOfRows" : 1,
        "stDate" : 20200101,
        "edDate" : 20220525,
        "pageNo" : i
    }

    result = requests.get('http://data.ex.co.kr/openapi/trafficOprgPrcd/trafficFlowBySpeed', keyDict)
    if(result.status_code != 200):
        break;
        
    resultList.append(json.loads(result.text))

# %%
tempList = []
for i in resultList:
    tempList.append(resultList)

tempList = 
type(tempList[0])
# Out:
# dict

# %%
output = json.dumps(list([x for x in resultList]))
with open('data.json', 'w', encoding='utf-8') as f:
    json.dump(output, f, ensure_ascii=False, indent=4)

# %%
keyDict = {
    "key" : "5261015714",
    "type" : "json",
    "numOfRows" : 99,
    "stDate" : 20200101,
    "edDate" : 20220525,
    "pageNo" : 1
}

result = requests.get('http://data.ex.co.kr/openapi/trafficOprgPrcd/trafficFlowBySpeed', keyDict)
print(json.loads(result.text))
# Out:
# {'count': 88027, 'pageNo': 1, 'numOfRows': 99, 'pageSize': 890, 'trafficFlowBySpeedLists': [{'tcsCarTypeCd': '1', 'tcsCarTypeNm': '1종', 'tcsCarTypeGrpNm': '소형차', 'tcsCarTypeGrpCd': '1', 'stDate': None, 'edDate': None, 'oDate': '2020.01.01(수)', 'stdSpeedCd': '1', 'trafficFlow': '192496', 'stdSpeedNm': '10KM/H미만', 'message': None, 'code': None}, {'tcsCarTypeCd': '2', 'tcsCarTypeNm': '2종', 'tcsCarTypeGrpNm': '중형차', 'tcsCarTypeGrpCd': '2', 'stDate': None, 'edDate': None, 'oDate': '2020.01.01(수)', 'stdSpeedCd': '1', 'trafficFlow': '10919', 'stdSpeedNm': '10KM/H미만', 'message': None, 'code': None}, {'tcsCarTypeCd': '3', 'tcsCarTypeNm': '3종', 'tcsCarTypeGrpNm': '대형차', 'tcsCarTypeGrpCd': '3', 'stDate': None, 'edDate': None, 'oDate': '2020.01.01(수)', 'stdSpeedCd': '1', 'trafficFlow': '17218', 'stdSpeedNm': '10KM/H미만', 'message': None, 'code': None}, {'tcsCarTypeCd': '4', 'tcsCarTypeNm': '4종', 'tcsCarTypeGrpNm': '대형차', 'tcsCarTypeGrpCd': '3', 'stDate': None, 'edDate': None, 'oDate': '2020.01.01(수)', 'stdSpeedCd': '1', 'trafficFlow': '15341', 'stdSpeedNm': '10KM/H미만', 'message': None, 'code': None}, {'tcsCarTypeCd': '5', 'tcsCarTypeNm': '5종', 'tcsCarTypeGrpNm': '대형차', 'tcsCarTypeGrpCd': '3', 'stDate': None, 'edDate': None, 'oDate': '2020.01.01(수)', 'stdSpeedCd': '1', 'trafficFlow': '11079', 'stdSpeedNm': '10KM/H미만', 'message': None, 'code': None}, {'tcsCarTypeCd': '6', 'tcsCarTypeNm': '6종', 'tcsCarTypeGrpNm': '소형차', 'tcsCarTypeGrpCd': '1', 'stDate': None, 'edDate': None, 'oDate': '2020.01.01(수)', 'stdSpeedCd': '1', 'trafficFlow': '8602', 'stdSpeedNm': '10KM/H미만', 'message': None, 'code': None}, {'tcsCarTypeCd': '1', 'tcsCarTypeNm': '1종', 'tcsCarTypeGrpNm': '소형차', 'tcsCarTypeGrpCd': '1', 'stDate': None, 'edDate': None, 'oDate': '2020.01.01(수)', 'stdSpeedCd': '2', 'trafficFlow': '488', 'stdSpeedNm': '10~20KM/H', 'message': None, 'code': None}, {'tcsCarTypeCd': '2', 'tcsCarTypeNm': '2종', 'tcsCarTypeGrpNm': '중형차', 'tcsCarTypeGrpCd': '2', 'stDate': None, 'edDate': None, 'oDate': '2020.01.01(수)', 'stdSpeedCd': '2', 'trafficFlow': '33', 'stdSpeedNm': '10~20KM/H', 'message': None, 'code': None}, {'tcsCarTypeCd': '3', 'tcsCarTypeNm': '3종', 'tcsCarTypeGrpNm': '대형차', 'tcsCarTypeGrpCd': '3', 'stDate': None, 'edDate': None, 'oDate': '2020.01.01(수)', 'stdSpeedCd': '2', 'trafficFlow': '58', 'stdSpeedNm': '10~20KM/H', 'message': None, 'code': None}, {'tcsCarTypeCd': '4', 'tcsCarTypeNm': '4종', 'tcsCarTypeGrpNm': '대형차', 'tcsCarTypeGrpCd': '3', 'stDate': None, 'edDate': None, 'oDate': '2020.01.01(수)', 'stdSpeedCd': '2', 'trafficFlow': '40', 'stdSpeedNm': '10~20KM/H', 'message': None, 'code': None}, {'tcsCarTypeCd': '5', 'tcsCarTypeNm': '5종', 'tcsCarTypeGrpNm': '대형차', 'tcsCarTypeGrpCd': '3', 'stDate': None, 'edDate': None, 'oDate': '2020.01.01(수)', 'stdSpeedCd': '2', 'trafficFlow': '42', 'stdSpeedNm': '10~20KM/H', 'message': None, 'code': None}, {'tcsCarTypeCd': '6', 'tcsCarTypeNm': '6종', 'tcsCarTypeGrpNm': '소형차', 'tcsCarTypeGrpCd': '1', 'stDate': None, 'edDate': None, 'oDate': '2020.01.01(수)', 'stdSpeedCd': '2', 'trafficFlow': '122', 'stdSpeedNm': '10~20KM/H', 'message': None, 'code': None}, {'tcsCarTypeCd': '1', 'tcsCarTypeNm': '1종', 'tcsCarTypeGrpNm': '소형차', 'tcsCarTypeGrpCd': '1', 'stDate': None, 'edDate': None, 'oDate': '2020.01.01(수)', 'stdSpeedCd': '3', 'trafficFlow': '4518', 'stdSpeedNm': '20~30KM/H', 'message': None, 'code': None}, {'tcsCarTypeCd': '2', 'tcsCarTypeNm': '2종', 'tcsCarTypeGrpNm': '중형차', 'tcsCarTypeGrpCd': '2', 'stDate': None, 'edDate': None, 'oDate': '2020.01.01(수)', 'stdSpeedCd': '3', 'trafficFlow': '86', 'stdSpeedNm': '20~30KM/H', 'message': None, 'code': None}, {'tcsCarTypeCd': '3', 'tcsCarTypeNm': '3종', 'tcsCarTypeGrpNm': '대형차', 'tcsCarTypeGrpCd': '3', 'stDate': None, 'edDate': None, 'oDate': '2020.01.01(수)', 'stdSpeedCd': '3', 'trafficFlow': '102', 'stdSpeedNm': '20~30KM/H', 'message': None, 'code': None}, {'tcsCarTypeCd': '4', 'tcsCarTypeNm': '4종', 'tcsCarTypeGrpNm': '대형차', 'tcsCarTypeGrpCd': '3', 'stDate': None, 'edDate': None,  ...
