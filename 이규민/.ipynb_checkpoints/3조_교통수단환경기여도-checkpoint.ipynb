# %%
import os
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pylab as plt

plt.rc('font', family='Malgun Gothic', size = 18)
plt.rcParams['figure.figsize'] = (20, 10)
plt.rcParams['lines.linewidth'] = 2

import seaborn as sns

# %%
ptDF = pd.read_csv('../자료/행정동별대중교통수단통합.csv', sep=',', encoding='euc-kr')
ptDF
# Out:
#                기준_날짜  시작_행정동_ID  종료_행정동_ID    승객수
# 0         20220101.0  1112056.0  2305057.0    6.0
# 1         20220101.0  1113071.0  1113070.0   46.0
# 2         20220101.0  1102071.0  1125074.0    8.0
# 3         20220101.0  1105053.0  1110065.0  149.0
# 4         20220101.0  1104052.0  1102065.0   43.0
# ...              ...        ...        ...    ...
# 29993496  20220430.0  3102154.0  1104066.0    8.0
# 29993497  20220430.0  1112074.0  1115054.0    1.0
# 29993498  20220430.0  2308060.0  1123066.0    3.0
# 29993499  20220430.0  1123052.0  1123052.0  966.0
# 29993500  20220430.0  1120067.0  1114076.0    5.0
#
# [29993501 rows x 4 columns]

# %%
ptDF.info()
ptDF.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29993501 entries, 0 to 29993500
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   기준_날짜      float64
#  1   시작_행정동_ID  float64
#  2   종료_행정동_ID  float64
#  3   승객수        float64
# dtypes: float64(4)
# memory usage: 915.3 MB
#               기준_날짜     시작_행정동_ID     종료_행정동_ID           승객수
# count  2.999350e+07  2.999350e+07  2.999350e+07  2.999350e+07
# mean   1.868193e+07  1.592061e+06  1.585504e+06  2.718746e+01
# std    5.360899e+06  8.410228e+05  8.373630e+05  9.786054e+01
# min    0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# 25%    2.022012e+07  1.109073e+06  1.109072e+06  2.000000e+00
# 50%    2.022030e+07  1.119062e+06  1.119061e+06  4.000000e+00
# 75%    2.022040e+07  2.303062e+06  2.301065e+06  1.600000e+01
# max    2.022043e+07  4.413358e+06  4.413358e+06  1.160000e+04

# %%
for i in ptDF.columns[:3]:
    ptDF[i] = ptDF[i].astype('str')
ptDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29993501 entries, 0 to 29993500
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   기준_날짜      object
#  1   시작_행정동_ID  object
#  2   종료_행정동_ID  object
#  3   승객수        float64
# dtypes: float64(1), object(3)
# memory usage: 915.3+ MB

# %%
shGroup = ptDF.groupby(ptDF.columns[1:3]).agg('sum')
shGroup.head(len(shGroup))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [57], in <cell line: 1>()
# ----> 1 wow, shGroup = ptDF.groupby(ptDF.columns[1:3]).agg('sum')
#       2 shGroup.head(len(shGroup))
#
# File ~\anaconda3\envs\three\lib\site-packages\pandas\core\frame.py:7712, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7707 axis = self._get_axis_number(axis)
#    7709 # https://github.com/python/mypy/issues/7642
#    7710 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7711 # "Union[bool, NoDefault]"; expected "bool"
# -> 7712 return DataFrameGroupBy(
#    7713     obj=self,
#    7714     keys=by,
#    7715     axis=axis,
#    7716     level=level,
#    7717     as_index=as_index,
#    7718     sort=sort,
#    7719     group_keys=group_keys,
#    7720     squeeze=squeeze,  # type: ignore[arg-type]
# ...
