# %%
import os
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pylab as plt
import seaborn as sns

dataPath = (os.getcwd().replace("\\", "/")) + "/자료/"
nonSharedDataPath = os.getcwd().replace("\\", "/") + "/../공유못함/"

# 자료부르기 예제
# df = pd.read_csv(dataPath + 'seoul_nav.csv', sep=',', encoding='utf8')
# df = pd.read_csv(nonSharedDataPath + '행정동별대중교통수단통합.csv', sep=',', encoding='euc-kr')

# %%
#이규민

# %%
plt.rc('font', family='Malgun Gothic', size = 18)
plt.rcParams['figure.figsize'] = (20, 10)
plt.rcParams['lines.linewidth'] = 2

# %%
carHavingDF = pd.read_csv(dataPath + '행정동별차량현황.csv', sep=',', encoding='euc-kr')
carMovingDF = pd.read_csv(dataPath + '행정동별통행량현황.csv', sep=',', encoding='euc-kr')
pubilcMovingDF = pd.read_csv(dataPath + '대중교통행정동별현황.csv', sep=',', encoding='euc-kr')

# %%
#평균재차인원 : 1.22 출처 : https://www.joongang.co.kr/article/22626529#home
carMovingDF = carMovingDF.reindex(columns=['일자', '통행량', '읍면동', '행정동코드', '시군구', '행정구코드'])
carMovingDF
# Out:
#             일자     통행량    읍면동    행정동코드   시군구  행정구코드
# 0     20220101  175685    가산동  1118051   금천구  11180
# 1     20220101   55845    개봉동  1117064   구로구  11170
# 2     20220101  210029    방화동  1116070   강서구  11160
# 3     20220101   83705    고덕동  1125055   강동구  11250
# 4     20220101   92723    공릉동  1111056   노원구  11110
# ...        ...     ...    ...      ...   ...    ...
# 8875  20220430  131216    합정동  1114068   마포구  11140
# 8876  20220430   69647    홍은동  1113066  서대문구  11130
# 8877  20220430   38330    화곡동  1116055   강서구  11160
# 8878  20220430   38329    황학동  1102067    중구  11020
# 8879  20220430    9265  회현동1가  1102054    중구  11020
#
# [8880 rows x 6 columns]

# %%
pubilcMovingDF
# Out:
#              일자    승객수  읍면동    행정동코드  시군구  행정구코드
# 0      20220101  20524  사직동  1101053  종로구  11010
# 1      20220102  21701  사직동  1101053  종로구  11010
# 2      20220103  54331  사직동  1101053  종로구  11010
# 3      20220104  57510  사직동  1101053  종로구  11010
# 4      20220105  58347  사직동  1101053  종로구  11010
# ...         ...    ...  ...      ...  ...    ...
# 47058  20220426   1183   길동  1125074  강동구  11250
# 47059  20220427  16513   길동  1125074  강동구  11250
# 47060  20220428  16654   길동  1125074  강동구  11250
# 47061  20220429  17058   길동  1125074  강동구  11250
# 47062  20220430  12750   길동  1125074  강동구  11250
#
# [47063 rows x 6 columns]

# %%
carHavingDF
# Out:
#       차종종별            연료     건수        비율   읍면동    행정동코드   시군구  행정구코드
# 0       승용            경유  36691  0.168009   여의동  1119054  영등포구  11190
# 1       승용       휘발유(무연)  34512  0.158031   여의동  1119054  영등포구  11190
# 2       승용           휘발유  33805  0.154794   여의동  1119054  영등포구  11190
# 3       승용       휘발유(무연)  28889  0.132283  역삼1동  1123064   강남구  11230
# 4       승용       휘발유(무연)  28016  0.128286  가양1동  1116064   강서구  11160
# ...    ...           ...    ...       ...   ...      ...   ...    ...
# 19216   승용       휘발유(유연)      1  0.000005  청량리동  1106080  동대문구  11060
# 19217   승합          기타연료      1  0.000005  청량리동  1106080  동대문구  11060
# 19218   승용  하이브리드(경유+전기)      1  0.000005  불광1동  1112052   은평구  11120
# 19219   특수           휘발유      1  0.000005  일원본동  1123072   강남구  11230
# 19220   승합           엘피지      1  0.000005  신당5동  1102065    중구  11020
#
# [19221 rows x 8 columns]

# %%
coronaDF = pd.read_csv(dataPath + '행정구별코로나발생수.csv', encoding='euc-kr')
coronaDF
# Out:
#            일자    종로구  종로구 추가     중구  중구 추가    용산구  용산구 추가     성동구  성동구 추가  \
# 0    20220430  46744      74  42410     66  70764     117  102422     180
# 1    20220429  46670     101  42344    121  70647     175  102242     215
# 2    20220428  46569      99  42223    119  70472     153  102027     233
# 3    20220427  46471     143  42103    115  70319     249  101795     268
# 4    20220426  46328     178  41988    175  70070     314  101527     429
# ..        ...    ...     ...    ...    ...    ...     ...     ...     ...
# 115  20220105   4056      21   3784     20   5427      39    5867      38
# 116  20220104   4035      13   3764     17   5388      23    5829      20
# 117  20220103   4022      12   3747     21   5365      20    5809      34
# 118  20220102   4010      17   3726     26   5346      35    5775      27
# 119  20220101   3993      20   3700     29   5311      37    5748      41
#
#         광진구  ...     서초구  서추구 추가     강남구  강남구 추가     송파구  송파구 추가     강동구  \
# ...

# %%
carMovingDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8880 entries, 0 to 8879
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   일자      8880 non-null   int64
#  1   통행량     8880 non-null   int64
#  2   읍면동     8880 non-null   object
#  3   행정동코드   8880 non-null   int64
#  4   시군구     8880 non-null   object
#  5   행정구코드   8880 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 416.4+ KB

# %%
carMovingDF['일자'] = carMovingDF['일자'].astype('str')
carMovingDF[carMovingDF.columns[2:]] = carMovingDF[carMovingDF.columns[2:]].astype('str')
carMovingDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8880 entries, 0 to 8879
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   일자      8880 non-null   object
#  1   통행량     8880 non-null   int64
#  2   읍면동     8880 non-null   object
#  3   행정동코드   8880 non-null   object
#  4   시군구     8880 non-null   object
#  5   행정구코드   8880 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 416.4+ KB

# %%
carHavingDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19221 entries, 0 to 19220
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   차종종별    19221 non-null  object
#  1   연료      19221 non-null  object
#  2   건수      19221 non-null  int64
#  3   비율      19221 non-null  float64
#  4   읍면동     19221 non-null  object
#  5   행정동코드   19221 non-null  int64
#  6   시군구     19221 non-null  object
#  7   행정구코드   19221 non-null  int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 1.2+ MB

# %%
carHavingDF[carHavingDF.columns[5:]] = carHavingDF[carHavingDF.columns[5:]].astype('str')
carHavingDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19221 entries, 0 to 19220
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   차종종별    19221 non-null  object
#  1   연료      19221 non-null  object
#  2   건수      19221 non-null  int64
#  3   비율      19221 non-null  float64
#  4   읍면동     19221 non-null  object
#  5   행정동코드   19221 non-null  object
#  6   시군구     19221 non-null  object
#  7   행정구코드   19221 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 1.2+ MB

# %%
pubilcMovingDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47063 entries, 0 to 47062
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   일자      47063 non-null  int64
#  1   승객수     47063 non-null  int64
#  2   읍면동     46730 non-null  object
#  3   행정동코드   47063 non-null  int64
#  4   시군구     46730 non-null  object
#  5   행정구코드   47063 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 2.2+ MB

# %%
pubilcMovingDF['일자'] = pubilcMovingDF['일자'].astype('str')
pubilcMovingDF[pubilcMovingDF.columns[3:]] = pubilcMovingDF[pubilcMovingDF.columns[3:]].astype('str')
pubilcMovingDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47063 entries, 0 to 47062
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   일자      47063 non-null  object
#  1   승객수     47063 non-null  int64
#  2   읍면동     46730 non-null  object
#  3   행정동코드   47063 non-null  object
#  4   시군구     47063 non-null  object
#  5   행정구코드   47063 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 2.2+ MB

# %%
coronaDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 53 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   일자       120 non-null    int64
#  1   종로구      120 non-null    int64
#  2   종로구 추가   120 non-null    int64
#  3   중구       120 non-null    int64
#  4   중구 추가    120 non-null    int64
#  5   용산구      120 non-null    int64
#  6   용산구 추가   120 non-null    int64
#  7   성동구      120 non-null    int64
#  8   성동구 추가   120 non-null    int64
#  9   광진구      120 non-null    int64
#  10  광진구 추가   120 non-null    int64
#  11  동대문구     120 non-null    int64
#  12  동대문구 추가  120 non-null    int64
#  13  중랑구      120 non-null    int64
#  14  중랑구 추가   120 non-null    int64
#  15  성북구      120 non-null    int64
#  16  성북구 추가   120 non-null    int64
#  17  강북구      120 non-null    int64
#  18  강북구 추가   120 non-null    int64
#  19  도봉구      120 non-null    int64
#  20  도봉구 추가   120 non-null    int64
# ...

# %%
coronaDF['일자'] = coronaDF['일자'].astype('str')
coronaDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 53 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   일자       120 non-null    object
#  1   종로구      120 non-null    int64
#  2   종로구 추가   120 non-null    int64
#  3   중구       120 non-null    int64
#  4   중구 추가    120 non-null    int64
#  5   용산구      120 non-null    int64
#  6   용산구 추가   120 non-null    int64
#  7   성동구      120 non-null    int64
#  8   성동구 추가   120 non-null    int64
#  9   광진구      120 non-null    int64
#  10  광진구 추가   120 non-null    int64
#  11  동대문구     120 non-null    int64
#  12  동대문구 추가  120 non-null    int64
#  13  중랑구      120 non-null    int64
#  14  중랑구 추가   120 non-null    int64
#  15  성북구      120 non-null    int64
#  16  성북구 추가   120 non-null    int64
#  17  강북구      120 non-null    int64
#  18  강북구 추가   120 non-null    int64
#  19  도봉구      120 non-null    int64
#  20  도봉구 추가   120 non-null    int64
# ...

# %%
#carMovingDF 이상치처리
carMovingDF.describe()
# Out:
#                  통행량
# count    8880.000000
# mean    95589.997523
# std     84932.008940
# min         0.000000
# 25%     36452.250000
# 50%     61902.500000
# 75%    137169.750000
# max    426855.000000

# %%
carMovingDF[carMovingDF['통행량'] == 0]
# Out:
#             일자  통행량    읍면동    행정동코드   시군구  행정구코드
# 37    20220101    0    신촌동  1113075  서대문구  11130
# 55    20220101    0    잠원동  1122055   서초구  11220
# 111   20220102    0    신촌동  1113075  서대문구  11130
# 129   20220102    0    잠원동  1122055   서초구  11220
# 175   20220103    0    수색동  1112068   은평구  11120
# ...        ...  ...    ...      ...   ...    ...
# 8633  20220427    0  을지로2가  1102060    중구  11020
# 8684  20220428    0    송파동  1124061   송파구  11240
# 8707  20220428    0  을지로2가  1102060    중구  11020
# 8758  20220429    0    송파동  1124061   송파구  11240
# 8832  20220430    0    송파동  1124061   송파구  11240
#
# [372 rows x 6 columns]

# %%
carMeanDF = carMovingDF.groupby(['일자', '시군구'], as_index=False).agg('mean')
carMeanDF
# Out:
#             일자  시군구            통행량
# 0     20220101  강남구   69961.833333
# 1     20220101  강동구   42256.666667
# 2     20220101  강서구   85210.333333
# 3     20220101  관악구   26371.000000
# 4     20220101  광진구   46079.000000
# ...        ...  ...            ...
# 2755  20220430  용산구  134802.000000
# 2756  20220430  은평구   87793.500000
# 2757  20220430  종로구   31554.250000
# 2758  20220430   중구   38259.600000
# 2759  20220430  중랑구  164926.000000
#
# [2760 rows x 3 columns]

# %%
#fillna를 대신할 함수
def fillMean(x):
    for i in carMeanDF.index:
        if((x[0] == carMeanDF.iloc[i, 0]) & (x[4] == carMeanDF.iloc[i, 1])):
            x[1] = carMeanDF.iloc[i, 2]
            break;
    return x

carMovingDF[carMovingDF['통행량'] == 0] = carMovingDF[carMovingDF['통행량'] == 0].apply(fillMean ,1)
carMovingDF[carMovingDF['통행량'] == 0]
# Out:
# Empty DataFrame
# Columns: [일자, 통행량, 읍면동, 행정동코드, 시군구, 행정구코드]
# Index: []

# %%
pubilcMovingDF.describe()
# Out:
#                  승객수
# count   47063.000000
# mean    13818.151414
# std     16701.751945
# min        14.000000
# 25%      4356.000000
# 50%      8045.000000
# 75%     16331.500000
# max    171577.000000

# %%
coronaDF.describe()
# Out:
#                 종로구       종로구 추가            중구       중구 추가           용산구  \
# count    120.000000   120.000000    120.000000   120.00000    120.000000
# mean   19914.283333   356.450000  18131.200000   323.15000  29667.608333
# std    16571.797840   381.486871  14955.695332   345.39622  25020.036536
# min     3993.000000     6.000000   3700.000000    10.00000   5311.000000
# 25%     4712.250000    52.750000   4430.250000    42.00000   6672.750000
# 50%    11700.500000   208.500000  10640.000000   177.00000  17512.500000
# 75%    38161.000000   539.750000  34524.000000   490.00000  56738.500000
# max    46744.000000  1826.000000  42410.000000  1761.00000  70764.000000
#
#             용산구 추가            성동구       성동구 추가            광진구       광진구 추가  \
# count   120.000000     120.000000   120.000000     120.000000   120.000000
# mean    545.591667   42006.625000   806.025000   50390.083333   963.791667
# std     572.309350   37493.804122   829.285421   44469.168323   958.179400
# ...

# %%
carHavingDF.describe()
# Out:
#                  건수            비율
# count  19221.000000  19221.000000
# mean    1134.540034      0.005195
# std     2709.821403      0.012408
# min        1.000000      0.000005
# 25%        6.000000      0.000027
# 50%       27.000000      0.000124
# 75%      642.000000      0.002940
# max    36691.000000      0.168009

# %%
#일별 자치구별 코로나 증가현황
onlyCoronaDF = coronaDF[coronaDF.columns[0::2]]
onlyCoronaDF.sort_values('일자', inplace=True)
onlyCoronaDF
# Out:
# <ipython-input-35-66775522f280>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   onlyCoronaDF.sort_values('일자', inplace=True)
#            일자  종로구 추가  중구 추가  용산구 추가  성동구 추가  광진구 추가  동대문구 추가  중랑구 추가  성북구 추가  \
# 119  20220101      20     29      37      41      34       74      58      56
# 118  20220102      17     26      35      27      33       36      48      48
# 117  20220103      12     21      20      34      27       38      42      36
# 116  20220104      13     17      23      20      28       32      46      48
# 115  20220105      21     20      39      38      52       66      71      62
# ..        ...     ...    ...     ...     ...     ...      ...     ...     ...
# 4    20220426     178    175     314     429     450      468     530     571
# ...

# %%
for i in range(1, len(onlyCoronaDF.columns), 2):
    plt.plot(onlyCoronaDF['일자'], onlyCoronaDF[onlyCoronaDF.columns[i]], label=onlyCoronaDF.columns[i])
    
plt.rcParams['figure.figsize'] = (20, 10)
plt.rc('font', family='Malgun Gothic', size = 18)
plt.xticks(list([x for x in range(0, 120,  6)]), rotation=90)
plt.legend()

# %%
#종로구 교통현황 변화 보기

# %%
#우찬희

# %%
#김태훈

# %%
df = pd.read_excel(dataPath + '전기차충전기위치.xlsx')
df
# Out:
#                     충전소명                   충전기타입     충전기상태  \
# 0               종묘 공영주차장        03(DC 차데모+AC 3상)  9(상태미확인)
# 1              세종로 공영주차장  06(DC 차데모+AC 3상+DC 콤보)  9(상태미확인)
# 2             그랜드앰배서더 서울  06(DC 차데모+AC 3상+DC 콤보)  9(상태미확인)
# 3             한강진역 공영주차장        03(DC 차데모+AC 3상)  9(상태미확인)
# 4       마장동사무소 앞(공중전화부스)  06(DC 차데모+AC 3상+DC 콤보)  9(상태미확인)
# ...                  ...                     ...       ...
# 117212       영남알프스복합웰컴센터               04(DC 콤보)   2(충전대기)
# 117213        언양읍 행정복지센터               04(DC 콤보)   2(충전대기)
# 117214        화봉공원 공영주차장  06(DC 차데모+AC 3상+DC 콤보)   2(충전대기)
# 117215        화봉공원 공영주차장  06(DC 차데모+AC 3상+DC 콤보)   2(충전대기)
# 117216         낙산해수욕장주차장  06(DC 차데모+AC 3상+DC 콤보)  9(상태미확인)
#
#                               주소
# 0               서울특별시 종로구 종로 157
# 1             서울특별시 종로구 세종대로 189
# 2               서울특별시 중구 동호로 287
# 3           서울특별시 용산구 한남동 산10-84
# 4              서울특별시 성동구 마장동 808
# ...                          ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117217 entries, 0 to 117216
# Data columns (total 4 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   충전소명    117217 non-null  object
#  1   충전기타입   117217 non-null  object
#  2   충전기상태   117217 non-null  object
#  3   주소      117217 non-null  object
# dtypes: object(4)
# memory usage: 3.6+ MB

# %%
df['주소'][0].split()
# Out:
# ['서울특별시', '종로구', '종로', '157']

# %%
df['주소']
# Out:
# 0                 서울특별시 종로구 종로 157
# 1               서울특별시 종로구 세종대로 189
# 2                 서울특별시 중구 동호로 287
# 3             서울특별시 용산구 한남동 산10-84
# 4                서울특별시 성동구 마장동 808
#                     ...
# 117212    울산광역시 울주군 상북면 등억알프스리 517
# 117213         울산광역시 울주군 언양읍 동문길 7
# 117214          울산광역시 북구 화봉동 445-1
# 117215          울산광역시 북구 화봉동 445-1
# 117216          강원도 양양군 강현면 일출로 43
# Name: 주소, Length: 117217, dtype: object

# %%
df['주소'][4].split()[0] == '서울특별시'
# Out:
# True

# %%
type(df.iloc[4])
# Out:
# pandas.core.series.Series

# %%
df2 = pd.DataFrame()
df2
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
check = []
for i in range(len(df)):
    if df['주소'][i].split()[0] == '서울특별시':
        check.append(True)
    else:
        check.append(False)
df[check]
# Out:
#                     충전소명                   충전기타입     충전기상태  \
# 0               종묘 공영주차장        03(DC 차데모+AC 3상)  9(상태미확인)
# 1              세종로 공영주차장  06(DC 차데모+AC 3상+DC 콤보)  9(상태미확인)
# 2             그랜드앰배서더 서울  06(DC 차데모+AC 3상+DC 콤보)  9(상태미확인)
# 3             한강진역 공영주차장        03(DC 차데모+AC 3상)  9(상태미확인)
# 4       마장동사무소 앞(공중전화부스)  06(DC 차데모+AC 3상+DC 콤보)  9(상태미확인)
# ...                  ...                     ...       ...
# 117183         사당 롯데캐슬샤인               02(AC 완속)  9(상태미확인)
# 117184         사당 롯데캐슬샤인               02(AC 완속)  9(상태미확인)
# 117185       목동 삼성쉐르빌1상가               02(AC 완속)  9(상태미확인)
# 117186       목동 삼성쉐르빌1상가               02(AC 완속)  9(상태미확인)
# 117187       목동 삼성쉐르빌1상가               02(AC 완속)  9(상태미확인)
#
#                           주소
# 0           서울특별시 종로구 종로 157
# 1         서울특별시 종로구 세종대로 189
# 2           서울특별시 중구 동호로 287
# 3       서울특별시 용산구 한남동 산10-84
# 4          서울특별시 성동구 마장동 808
# ...                      ...
# 117183  서울특별시 동작구 사당로27길 190
# ...

# %%
df3 = pd.read_excel(dataPath + '서울시_자동차_등록현황(연료별)통계.xls')
df3 = df3.fillna(0)
df3
# Out:
#       기간  차종별        계      휘발유       경유     LPG     전기   CNG     하이브리드  \
# 0   2018    계  3124651  1592471  1147787  284328   9564  9635   75178.0
# 1   2018  승용차  2658637  1589567   744280  239192   9507   597   75126.0
# 2   2018  승합차   120780     1059    93190   16699     33  8621      52.0
# 3   2018  화물차   337241     1827   302557   28357     23   414       0.0
# 4   2018  특수차     7993       18     7760      80      1     3       0.0
# 5   2019    계  3124157  1607915  1121920  271977  14952  9441   91505.0
# 6   2019  승용차  2670803  1604962   727757  231089  14232   510   91453.0
# 7   2019  승합차   114310     1002    88472   14864    127  8529      52.0
# 8   2019  화물차   330840     1933   297709   25942    592   400       0.0
# 9   2019  특수차     8204       18     7982      82      1     2       0.0
# 10  2020    계  3157361  1634867  1108287  258444  23393  9114  115280.0
# 11  2020  승용차  2711984  1631306   722122  220302  20763   435  115228.0
# ...

# %%
df3 = df3[df3['차종별']=='계']
df3 = df3.reset_index(drop=True)
df3 = df3.rename(columns={'계':'자동차등록대수(전체)'})
df3
# Out:
#      기간 차종별  자동차등록대수(전체)      휘발유       경유     LPG     전기   CNG     하이브리드  \
# 0  2018   계      3124651  1592471  1147787  284328   9564  9635   75178.0
# 1  2019   계      3124157  1607915  1121920  271977  14952  9441   91505.0
# 2  2020   계      3157361  1634867  1108287  258444  23393  9114  115280.0
# 3  2021   계      3176743  1646141  1084741  245041  40564  8887  141889.0
#
#        수소    기타
# 0    84.0  5604
# 1   599.0  5848
# 2  1671.0  6305
# 3  2445.0  7035

# %%
df4 = df3[['휘발유','경유','LPG','전기','CNG','하이브리드','수소','기타']]
df4 = df4.T
df4.columns = ['2018','2019','2020','2021']
df4 = df4.reset_index()
df4 = df4.rename(columns={'index':'연료'})
# df4 = df4.T.reset_index()
# df4 = df4.rename(columns={'index':'기간'})
df4
# Out:
#       연료       2018       2019       2020       2021
# 0    휘발유  1592471.0  1607915.0  1634867.0  1646141.0
# 1     경유  1147787.0  1121920.0  1108287.0  1084741.0
# 2    LPG   284328.0   271977.0   258444.0   245041.0
# 3     전기     9564.0    14952.0    23393.0    40564.0
# 4    CNG     9635.0     9441.0     9114.0     8887.0
# 5  하이브리드    75178.0    91505.0   115280.0   141889.0
# 6     수소       84.0      599.0     1671.0     2445.0
# 7     기타     5604.0     5848.0     6305.0     7035.0

# %%
import numpy as np

# spot_ = 2018
# d_ = df3[(df3["기간"]==spot_) & (df["일시"].dt.month==9)]


plt.figure(figsize=(15,10))
plt.rc('font', family='Malgun Gothic', size = 10)
plt.title("년도별 자동차 등록대수" , fontsize=15)
plt.plot(df3["기간"], df3["자동차등록대수(전체)"], "-", color='black')
plt.grid()
plt.xticks([2018,2019,2020,2021])
plt.show()

# %%
# plt.figure(figsize=(15,10))
# plt.title("년도별 전기차 등록대수" , fontsize=15)
# plt.plot(df3["기간"], df3["전기"], "-", color='blue')
# plt.grid()
# plt.xticks([2018,2019,2020,2021])
# plt.show()

plt.figure(figsize=(10,8)) # 먼저 창을 만들고
n=1
color_list = ['#ffd500','blue','#fc5a03','#03d3fc']
for spot_ in ['휘발유','경유','LPG','전기']:
    d_ = df4[(df4["연료"]==spot_)]
    ax = plt.subplot(2,2,n) # for문을 돌면서 Axes를 추가
    plt.title("%s 자동차 등록 현황" % spot_, fontsize=15)
    ax.plot(df3["기간"], df3[spot_], "-", color=color_list[n-1]) # 그래프 추가
    plt.xticks([2018,2019,2020,2021])
    plt.xlabel('년도')
    n+=1
plt.tight_layout()  # 창 크기에 맞게 조정
plt.show()

# %%
plt.figure(figsize=(10,8)) # 먼저 창을 만들고
n=1
color_list = ['red','blue','green','#e303fc']
for spot_ in ['CNG','하이브리드','수소','기타']:
    d_ = df4[(df4["연료"]==spot_)]
    ax = plt.subplot(2,2,n) # for문을 돌면서 Axes를 추가
    plt.title("%s 자동차 등록 현황" % spot_, fontsize=15)
    ax.plot(df3["기간"], df3[spot_], "-", color=color_list[n-1]) # 그래프 추가
    plt.xticks([2018,2019,2020,2021])
    plt.xlabel('년도')
    n+=1
plt.tight_layout()  # 창 크기에 맞게 조정
plt.show()

# %%
# # 충전소 정보 api (시간남으면 하기)

# import requests

# url = 'http://apis.data.go.kr/B552584/EvCharger/getChargerInfo'
# params ={'serviceKey' : 'CtFNdORsVsfnL5mw9qeUBn0ZoI99HOg3gpvyRWlatLXcG4F5zKL62gkGuw2mFY2lyu2sOzMDTB4Se3iasBBQsg%3D%3D',
#          'pageNo' : '1', 'numOfRows' : '10', 'zcode' : '11' }

# response = requests.get(url, params=params)
# print(response.content)

# %%
# # 충전소 정보 api (시간남으면 하기)

# import pandas
# from bs4 import BeautifulSoup
# import requests
# from openpyxl.workbook import Workbook

# # API Key(인증키 - serviceKey)..
# apikey='CtFNdORsVsfnL5mw9qeUBn0ZoI99HOg3gpvyRWlatLXcG4F5zKL62gkGuw2mFY2lyu2sOzMDTB4Se3iasBBQsg%3D%3D'
# numOfRows = 9999
# pageNo = 1
# #period = 5
# zcode = 11


# # URL
# api = "http://apis.data.go.kr/B552584/EvCharger/getChargerInfo?serviceKey={key}&numOfRows={nrow}&pageNo={pno}&zcode={zd}"
       
# for i in range(0,1):
#     url = api.format(key=apikey, nrow=numOfRows, pno=pageNo, zd=zcode)
#     req= requests.get(url)
#     re = req.text
#     soup = BeautifulSoup(re, 'html.parser')
#     print(soup)

# %%
#soup.find_all('addr')

# %%
# dd = []
# for i in range(len(soup.find_all('addr'))):
#     dd.append(soup.find_all('addr')[i].text.split()[0]=='서울특별시')
# dd

# %%
# 무의미한 그래프 (잘못그림)


# sns.set_palette('pastel')

# sns.barplot(x='2018', y='2020',hue='연료', data=df4)
# # 전체 그래프 제목 넣기
# plt.title('서울 전기차 등록대수')
# # x축 이름 넣기
# plt.xlabel('년도')
# # y축 이름 넣기
# plt.ylabel('등록대수')

# plt.show()

# %%
# 무의미한 그래프 (잘못그림)


# sns.set_palette('pastel')
# # 글자 크기 지정
# plt.rc('font', family='Malgun Gothic', size = 10)
# sns.barplot(x='기간', y='전기',hue='자동차등록대수(전체)', data=df3)
# # 전체 그래프 제목 넣기
# plt.title('서울 전기차 등록대수')
# # x축 이름 넣기
# plt.xlabel('년도')
# # y축 이름 넣기
# plt.ylabel('등록대수')

# ss = df3['휘발유']

# plt.legend(('ss','경유','LPG','전기'))

# plt.show()

# %%
#이주태

# %%
carHavingDF
# Out:
#       차종종별            연료     건수        비율   읍면동    행정동코드   시군구  행정구코드
# 0       승용            경유  36691  0.168009   여의동  1119054  영등포구  11190
# 1       승용       휘발유(무연)  34512  0.158031   여의동  1119054  영등포구  11190
# 2       승용           휘발유  33805  0.154794   여의동  1119054  영등포구  11190
# 3       승용       휘발유(무연)  28889  0.132283  역삼1동  1123064   강남구  11230
# 4       승용       휘발유(무연)  28016  0.128286  가양1동  1116064   강서구  11160
# ...    ...           ...    ...       ...   ...      ...   ...    ...
# 19216   승용       휘발유(유연)      1  0.000005  청량리동  1106080  동대문구  11060
# 19217   승합          기타연료      1  0.000005  청량리동  1106080  동대문구  11060
# 19218   승용  하이브리드(경유+전기)      1  0.000005  불광1동  1112052   은평구  11120
# 19219   특수           휘발유      1  0.000005  일원본동  1123072   강남구  11230
# 19220   승합           엘피지      1  0.000005  신당5동  1102065    중구  11020
#
# [19221 rows x 8 columns]

# %%
onlyCoronaDF
# Out:
#            일자  종로구 추가  중구 추가  용산구 추가  성동구 추가  광진구 추가  동대문구 추가  중랑구 추가  성북구 추가  \
# 119  20220101      20     29      37      41      34       74      58      56
# 118  20220102      17     26      35      27      33       36      48      48
# 117  20220103      12     21      20      34      27       38      42      36
# 116  20220104      13     17      23      20      28       32      46      48
# 115  20220105      21     20      39      38      52       66      71      62
# ..        ...     ...    ...     ...     ...     ...      ...     ...     ...
# 4    20220426     178    175     314     429     450      468     530     571
# 3    20220427     143    115     249     268     377      319     402     483
# 2    20220428      99    119     153     233     301      290     326     412
# 1    20220429     101    121     175     215     251      224     276     320
# 0    20220430      74     66     117     180     211      204     245     271
#
# ...

# %%
plt.plot(onlyCoronaDF)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-192-4b0b3470ca2b> in <module>
# ----> 1 plt.plot(onlyCoronaDF)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2759 @docstring.copy(Axes.plot)
#    2760 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
#    2763         is not None else {}), **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# ...

# %%
sns.heatmap(onlyCoronaDF)

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-193-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
ball = carHavingDF
ball
# Out:
#       차종종별            연료     건수        비율   읍면동    행정동코드   시군구  행정구코드
# 0       승용            경유  36691  0.168009   여의동  1119054  영등포구  11190
# 1       승용       휘발유(무연)  34512  0.158031   여의동  1119054  영등포구  11190
# 2       승용           휘발유  33805  0.154794   여의동  1119054  영등포구  11190
# 3       승용       휘발유(무연)  28889  0.132283  역삼1동  1123064   강남구  11230
# 4       승용       휘발유(무연)  28016  0.128286  가양1동  1116064   강서구  11160
# ...    ...           ...    ...       ...   ...      ...   ...    ...
# 19216   승용       휘발유(유연)      1  0.000005  청량리동  1106080  동대문구  11060
# 19217   승합          기타연료      1  0.000005  청량리동  1106080  동대문구  11060
# 19218   승용  하이브리드(경유+전기)      1  0.000005  불광1동  1112052   은평구  11120
# 19219   특수           휘발유      1  0.000005  일원본동  1123072   강남구  11230
# 19220   승합           엘피지      1  0.000005  신당5동  1102065    중구  11020
#
# [19221 rows x 8 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

# Plot miles per gallon against horsepower with other semantics
sns.relplot(x="건수", y="연료", hue="origin", size="weight",
            sizes=(40, 400), alpha=.5, palette="muted",
            height=6, data=ball)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-195-603a2c01c66c> in <module>
#       5
#       6 # Plot miles per gallon against horsepower with other semantics
# ----> 7 sns.relplot(x="건수", y="연료", hue="origin", size="weight",
#       8             sizes=(40, 400), alpha=.5, palette="muted",
#       9             height=6, data=ball)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#    1653
#    1654     # Use the full dataset to establish how to draw the semantics
# -> 1655     p = plotter(
#    1656         x=x, y=y, hue=hue, size=size, style=style, data=data,
# ...

# %%
sns.kdeplot(ball)
plt.title("교통량")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-196-2568d2ed6fcb> in <module>
# ----> 1 sns.kdeplot(ball)
#       2 plt.title("교통량")
#       3 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     662         return ax
#     663
# --> 664     data = data.astype(np.float64)
#     665     if data2 is not None:
#     666         if isinstance(data2, list):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
# ...

# %%
ax = plt.subplots()
ax = ball["비율"].plot.hist()

# %%
fig, ax = plt.subplots()
ax = ball[["건수", "비율"]].plot.hist(alpha=0, bins=20, ax=ax)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 44148 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 48708 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 50984 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 44148 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ...

# %%
ball1=onlyCoronaDF
ball1
# Out:
#            일자  종로구 추가  중구 추가  용산구 추가  성동구 추가  광진구 추가  동대문구 추가  중랑구 추가  성북구 추가  \
# 119  20220101      20     29      37      41      34       74      58      56
# 118  20220102      17     26      35      27      33       36      48      48
# 117  20220103      12     21      20      34      27       38      42      36
# 116  20220104      13     17      23      20      28       32      46      48
# 115  20220105      21     20      39      38      52       66      71      62
# ..        ...     ...    ...     ...     ...     ...      ...     ...     ...
# 4    20220426     178    175     314     429     450      468     530     571
# 3    20220427     143    115     249     268     377      319     402     483
# 2    20220428      99    119     153     233     301      290     326     412
# 1    20220429     101    121     175     215     251      224     276     320
# 0    20220430      74     66     117     180     211      204     245     271
#
# ...

# %%
# import 필요 / 
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax = onlyCoronaDF['종로구 추가'].plot.kde()
ax = onlyCoronaDF['중구 추가'].plot.kde()
ax = onlyCoronaDF['용산구 추가'].plot.kde()
ax = onlyCoronaDF['성동구 추가'].plot.kde()
ax = onlyCoronaDF['광진구 추가'].plot.kde()
ax = onlyCoronaDF['동대문구 추가'].plot.kde()
ax = onlyCoronaDF['중랑구 추가'].plot.kde()
ax = onlyCoronaDF['강북구 추가'].plot.kde()
ax = onlyCoronaDF['성북구 추가'].plot.kde()
ax = onlyCoronaDF['구로구 추가'].plot.kde()
ax = onlyCoronaDF['금천구 추가'].plot.kde()
ax = onlyCoronaDF['영등포구 추가'].plot.kde()
ax = onlyCoronaDF['동작구 추가'].plot.kde()
ax = onlyCoronaDF['관악구 추가'].plot.kde()

# %%
ball1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120 entries, 119 to 0
# Data columns (total 27 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   일자       120 non-null    object
#  1   종로구 추가   120 non-null    int64
#  2   중구 추가    120 non-null    int64
#  3   용산구 추가   120 non-null    int64
#  4   성동구 추가   120 non-null    int64
#  5   광진구 추가   120 non-null    int64
#  6   동대문구 추가  120 non-null    int64
#  7   중랑구 추가   120 non-null    int64
#  8   성북구 추가   120 non-null    int64
#  9   강북구 추가   120 non-null    int64
#  10  도봉구 추가   120 non-null    int64
#  11  노원구 추가   120 non-null    int64
#  12  은평구 추가   120 non-null    int64
#  13  서대문구 추가  120 non-null    int64
#  14  마포구 추가   120 non-null    int64
#  15  양천구 추가   120 non-null    int64
#  16  강서구 추가   120 non-null    int64
#  17  구로구 추가   120 non-null    int64
#  18  금천구 추가   120 non-null    int64
#  19  영등포구 추가  120 non-null    int64
#  20  동작구 추가   120 non-null    int64
# ...

# %%
# 새로운 컬럼 이름 만들기

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax = ball1.plot(index(1,27).kde()
# Out:
#   File "<ipython-input-202-1ab20f9fcf5c>", line 4
#     ax = ball1.plot(index(1,27).kde()
#                                      ^
# SyntaxError: unexpected EOF while parsing

# %%
ba112 =  ball1.piovt_table(
        columns='구이름')
 print('ball2')
# Out:
#   File "<ipython-input-203-cabaab01d3dd>", line 3
#     print('ball2')
#     ^
# IndentationError: unexpected indent

# %%
plt.plot(ball1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-204-3c188f071169> in <module>
# ----> 1 plt.plot(ball1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2759 @docstring.copy(Axes.plot)
#    2760 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
#    2763         is not None else {}), **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# ...

# %%
a = []
for n in range(1,50):
    a.append(n)
a

# %%
fig1 =  plt.figure()
plt.plot(ball1['종로구 추가'],"o")
plt.plot(ball1['중구 추가'],"o")
plt.plot(ball1['용산구 추가'],"o")
plt.plot(ball1['성동구 추가'],"o")
plt.plot(ball1['광진구 추가'],"o")
plt.plot(ball1['동대문구 추가'],"o")
plt.plot(ball1['중랑구 추가'],"o")
plt.plot(ball1['성북구 추가'],"o")
plt.plot(ball1['강북구 추가'],"o")
plt.plot(ball1['도봉구 추가'],"o")
plt.plot(ball1['노원구 추가'],"o")
plt.plot(ball1['은평구 추가'],"o")
plt.plot(ball1['서대문구 추가'],"o")
plt.plot(ball1['마포구 추가'],"o")
plt.plot(ball1['양천구 추가'],"o")
plt.plot(ball1['강서구 추가'],"o")
plt.plot(ball1['구로구 추가'],"o")
plt.plot(ball1['금천구 추가'],"o")
plt.plot(ball1['영등포구 추가'],"o")
plt.plot(ball1['동작구 추가'],"o")
plt.plot(ball1['관악구 추가'],"o")
plt.plot(ball1['서추구 추가'],"o")
plt.plot(ball1['강남구 추가'],"o")
plt.plot(ball1['송파구 추가'],"o")
plt.plot(ball1['강동구 추가'],"o")
plt.plot(ball1['기타 추가'],"o")

# %%
fig2 =  plt.figure()
plt.plot(ball1['종로구 추가'],"x")
plt.plot(ball1['중구 추가'],"x")
plt.plot(ball1['용산구 추가'],"x")
plt.plot(ball1['성동구 추가'],"x")
plt.plot(ball1['광진구 추가'],"x")
plt.plot(ball1['동대문구 추가'],"x")
plt.plot(ball1['중랑구 추가'],"x")
plt.plot(ball1['성북구 추가'],"x")
plt.plot(ball1['강북구 추가'],"x")
plt.plot(ball1['도봉구 추가'],"x")
plt.plot(ball1['노원구 추가'],"x")
plt.plot(ball1['은평구 추가'],"x")
plt.plot(ball1['서대문구 추가'],"x")
plt.plot(ball1['마포구 추가'],"x")
plt.plot(ball1['양천구 추가'],"x")
plt.plot(ball1['강서구 추가'],"x")
plt.plot(ball1['구로구 추가'],"x")
plt.plot(ball1['금천구 추가'],"x")
plt.plot(ball1['영등포구 추가'],"x")
plt.plot(ball1['동작구 추가'],"x")
plt.plot(ball1['관악구 추가'],"x")
plt.plot(ball1['서추구 추가'],"x")
plt.plot(ball1['강남구 추가'],"x")
plt.plot(ball1['송파구 추가'],"x")
plt.plot(ball1['강동구 추가'],"x")
plt.plot(ball1['기타 추가'],"x")

# %%
fig

# %%
fig3 =  plt.figure()
plt.plot(ball1['종로구 추가'],"x")
plt.plot(ball1['중구 추가'],"x")
plt.plot(ball1['용산구 추가'],"x")
plt.plot(ball1['성동구 추가'],"x")
plt.plot(ball1['광진구 추가'],"x")
plt.plot(ball1['동대문구 추가'],"x")
plt.plot(ball1['중랑구 추가'],"x")
plt.plot(ball1['성북구 추가'],"x")
plt.plot(ball1['강북구 추가'],"x")
plt.plot(ball1['도봉구 추가'],"x")
plt.plot(ball1['노원구 추가'],"x")
plt.plot(ball1['은평구 추가'],"x")
plt.plot(ball1['서대문구 추가'],"x")
plt.plot(ball1['마포구 추가'],"x")
plt.plot(ball1['양천구 추가'],"x")
plt.plot(ball1['강서구 추가'],"x")
plt.plot(ball1['구로구 추가'],"x")
plt.plot(ball1['금천구 추가'],"x")
plt.plot(ball1['영등포구 추가'],"x")
plt.plot(ball1['동작구 추가'],"x")
plt.plot(ball1['관악구 추가'],"x")
plt.plot(ball1['서추구 추가'],"x")
plt.plot(ball1['강남구 추가'],"x")
plt.plot(ball1['송파구 추가'],"x")
plt.plot(ball1['강동구 추가'],"x")
plt.plot(ball1['기타 추가'],"x")

# %%
fig2.tight_layout()
fig2

# %%
import plotly.express as px

ball4 = px.data.ball1()

fig = px.bar(ball4, x=" ", y=" ", color="medal", title=" ")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-210-2da8fc016e5c> in <module>
#       1 import plotly.express as px
#       2
# ----> 3 ball4 = px.data.ball1()
#       4
#       5 fig = px.bar(ball4, x=" ", y=" ", color="medal", title=" ")
#
# AttributeError: module 'plotly.express.data' has no attribute 'ball1'

# %%
ab =  ball1

# %%
ab
# Out:
#            일자  종로구 추가  중구 추가  용산구 추가  성동구 추가  광진구 추가  동대문구 추가  중랑구 추가  성북구 추가  \
# 119  20220101      20     29      37      41      34       74      58      56
# 118  20220102      17     26      35      27      33       36      48      48
# 117  20220103      12     21      20      34      27       38      42      36
# 116  20220104      13     17      23      20      28       32      46      48
# 115  20220105      21     20      39      38      52       66      71      62
# ..        ...     ...    ...     ...     ...     ...      ...     ...     ...
# 4    20220426     178    175     314     429     450      468     530     571
# 3    20220427     143    115     249     268     377      319     402     483
# 2    20220428      99    119     153     233     301      290     326     412
# 1    20220429     101    121     175     215     251      224     276     320
# 0    20220430      74     66     117     180     211      204     245     271
#
# ...

# %%
ab
ab
#ab.pivot(columns= "서울시 각 구")

# %%
sns.countplot(ab)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\utils.py in categorical_order(values, order)
#     543             try:
# --> 544                 order = values.cat.categories
#     545             except (TypeError, AttributeError):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#
# AttributeError: 'DataFrame' object has no attribute 'cat'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\utils.py in categorical_order(values, order)
#     546                 try:
# ...
